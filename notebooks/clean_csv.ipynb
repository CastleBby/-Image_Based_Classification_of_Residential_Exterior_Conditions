# %% [markdown]
# Due to mismatch in images and csv label rows, need to create a clean csv label file
#
# this is only ran once due to manual image data collection minor errors

# %%
import pandas as pd

df = pd.read_csv("../data/house_labels.csv")

df["image_name"] = df["image_number"].astype(str) + ".png"

df.to_csv("../data/house_labels.csv", index=False)

print("Updated image_name column with .png extension")
# Out:
# Updated image_name column with .png extension

# %% [markdown]
# error in labeling one image in the csv row

# %%
import pandas as pd

df = pd.read_csv("../data/house_labels.csv")

df.loc[df["image_name"] == "img_034.png", "label"] = "well_maintained"

df.to_csv("../data/house_labels.csv", index=False)

print("Updated img_034.png label")
# Out:
# Updated img_034.png label

# %%
find data/house_images -name ".DS_Store" -delete

# %%
import pandas as pd

df = pd.read_csv("../data/house_labels.csv")

df.loc[df["image_name"] == "img_073.png", "label"] = "poor"

df.to_csv("../data/house_labels.csv", index=False)

print("Updated img_073.png label")
# Out:
# Updated img_073.png label

# %%
import pandas as pd

df = pd.read_csv("../data/house_labels.csv")

df.loc[df["image_name"] == "img_034.png", "label"] = "well_maintained"

df.to_csv("../data/house_labels.csv", index=False)

print("Updated img_034.png label")

# %% [markdown]
# standardized label well-maintained to well_maintained

# %%
import pandas as pd

df = pd.read_csv("../data/house_labels.csv")

df["label"] = df["label"].replace("well-maintained", "well_maintained")

df.to_csv("../data/house_labels.csv", index=False)

print("Standardized labels to well_maintained")
# Out:
# Standardized labels to well_maintained
